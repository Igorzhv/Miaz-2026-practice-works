# %%
import pandas as pd

# %%
df = pd.read_csv('path_to_your_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv('path_to_your_dataset.csv')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path_to_your_dataset.csv'

# %%
import pandas as pd

df = pd.read_csv('data.csv')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('data.csv')
#       5 df.head()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.csv'

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\day2026\Documents\Miaz 2026 practice works\pr3.5

# %%
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(df.head())
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv('dataset.csv')

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('dataset.csv')
#       5 print(df.head())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset.csv'

# %%
print (df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print (df.head())
#
# NameError: name 'df' is not defined

# %%
pr3.5
    ├── modified_data.csv    ← ОЦЕ ТВОЯ БАЗА
    └── pr3_5.ipynb b
# Out:
#   Cell In[12], line 2
#     ├── modified_data.csv    ← ОЦЕ ТВОЯ БАЗА
#     ^
# SyntaxError: invalid character '├' (U+251C)

# %%
df = pd.read_csv('modified_data.csv')

# %%
import pandas as pd

df = pd.read_csv('modified_data.csv')

print(df.head())
# Out:
#          date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  2014-05-02   313000.0       3.0       1.50         1340      7912     1.5
# 1  2014-05-02  2384000.0       5.0       2.50         3650      9050     2.0
# 2  2014-05-02   342000.0       3.0       2.00         1930     11947     1.0
# 3  2014-05-02   420000.0       3.0       2.25         2000      8030     1.0
# 4  2014-05-02   550000.0       4.0       2.50         1940     10500     1.0
#
#    waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3        1340              0      1955
# 1           0     4          5        3370            280      1921
# 2           0     0          4        1930              0      1966
# 3           0     0          4        1000           1000      1963
# 4           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip  price_per_sqft
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133          233.58
# 1             0           709 W Blaine St    Seattle  WA 98119          653.15
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042          177.20
# 3             0           857 170th Pl NE   Bellevue  WA 98008          210.00
# 4          1992         9105 170th Ave NE    Redmond  WA 98052          283.51

# %%
print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\day2026\Documents\Miaz 2026 practice works\pr3.5
# ['modified_data.csv', 'pr3_5.ipynb']

# %%
print(df.isnull().sum())
# Out:
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# street            0
# city              0
# statezip          0
# price_per_sqft    0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True
# Out:
#   Cell In[19], line 1
#     df.fillna(df.mean(), inplace=True
#                                      ^
# SyntaxError: incomplete input

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of             date       price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-05-02   313000.00       3.0       1.50         1340      7912
# 1     2014-05-02  2384000.00       5.0       2.50         3650      9050
# 2     2014-05-02   342000.00       3.0       2.00         1930     11947
# 3     2014-05-02   420000.00       3.0       2.25         2000      8030
# 4     2014-05-02   550000.00       4.0       2.50         1940     10500
# ...          ...         ...       ...        ...          ...       ...
# 4595  2014-07-09   308166.67       3.0       1.75         1510      6360
# 4596  2014-07-09   534333.33       3.0       2.50         1460      7573
# 4597  2014-07-09   416904.17       3.0       2.50         3010      7014
# 4598  2014-07-10   203400.00       4.0       2.00         2090      6630
# 4599  2014-07-10   220600.00       3.0       2.50         1490      8102
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 0        1.5           0     0          3        1340              0
# 1        2.0           0     4          5        3370            280
# 2        1.0           0     0          4        1930              0
# 3        1.0           0     0          4        1000           1000
# 4        1.0           0     0          4        1140            800
# ...      ...         ...   ...        ...         ...            ...
# 4595     1.0           0     0          4        1510              0
# 4596     2.0           0     0          3        1460              0
# 4597     2.0           0     0          3        3010              0
# 4598     1.0           0     0          3        1070           1020
# 4599     2.0           0     0          4        1490              0
#
#       yr_built  yr_renovated                    street       city  statezip  \
# 0         1955          2005      18810 Densmore Ave N  Shoreline  WA 98133
# 1         1921             0           709 W Blaine St    Seattle  WA 98119
# 2         1966             0  26206-26214 143rd Ave SE       Kent  WA 98042
# 3         1963             0           857 170th Pl NE   Bellevue  WA 98008
# 4         1976          1992         9105 170th Ave NE    Redmond  WA 98052
# ...        ...           ...                       ...        ...       ...
# 4595      1954          1979            501 N 143rd St    Seattle  WA 98133
# 4596      1983          2009          14855 SE 10th Pl   Bellevue  WA 98007
# 4597      2009             0          759 Ilwaco Pl NE     Renton  WA 98059
# 4598      1974             0         5148 S Creston St    Seattle  WA 98178
# 4599      1990             0         18717 SE 258th St  Covington  WA 98042
#
#       price_per_sqft
# 0             233.58
# 1             653.15
# 2             177.20
# 3             210.00
# 4             283.51
# ...              ...
# 4595          204.08
# 4596          365.98
# 4597          138.51
# 4598           97.32
# 4599          148.05
#
# [4600 rows x 18 columns]>

# %%
   scaler = MinMaxScaler()
   df['scaled_columfloors'] = scaler.fit_transform(df[['numerical_column1']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 scaler = MinMaxScaler()
#       2 df['scaled_columfloors'] = scaler.fit_transform(df[['numerical_column1']])
#
# NameError: name 'MinMaxScaler' is not defined

# %%
scaler = MinMaxScaler()
df['bedrooms'] = scaler.fit_transform(df'22')
# Out:
#   Cell In[25], line 2
#     df['bedrooms'] = scaler.fit_transform(df'22')
#                                             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import os

# %%
print("Current folder:")
print(os.getcwd())
# Out:
# Current folder:
# c:\Users\day2026\Documents\Miaz 2026 practice works\pr3.5

# %%
print("\nFiles in folder:")
print(os.listdir())
# Out:
# Files in folder:
# ['modified_data.csv', 'pr3_5.ipynb']

# %%
df = pd.read_csv('modified_data.csv')

# %%
print("\nFirst 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#          date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  2014-05-02   313000.0       3.0       1.50         1340      7912     1.5
# 1  2014-05-02  2384000.0       5.0       2.50         3650      9050     2.0
# 2  2014-05-02   342000.0       3.0       2.00         1930     11947     1.0
# 3  2014-05-02   420000.0       3.0       2.25         2000      8030     1.0
# 4  2014-05-02   550000.0       4.0       2.50         1940     10500     1.0
#
#    waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3        1340              0      1955
# 1           0     4          5        3370            280      1921
# 2           0     0          4        1930              0      1966
# 3           0     0          4        1000           1000      1963
# 4           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip  price_per_sqft
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133          233.58
# 1             0           709 W Blaine St    Seattle  WA 98119          653.15
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042          177.20
# 3             0           857 170th Pl NE   Bellevue  WA 98008          210.00
# 4          1992         9105 170th Ave NE    Redmond  WA 98052          283.51

# %%
print(df.select_dtypes(include='number').columns)
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'price_per_sqft'],
#       dtype='str')

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.1-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\day2026\appdata\roaming\python\python311\site-packages (from scikit-learn) (2.4.6)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 650.1 kB/s eta 0:00:00
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Downloading joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.26.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting cloudpickle>=3.0 (from joblib>=1.4.0->scikit-learn)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Downloading scikit_learn-1.9.1-cp311-cp311-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.3 MB 3.6 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/8.3 MB 3.8 MB/s eta 0:00:03
#    --- ------------------------------------ 0.6/8.3 MB 5.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/8.3 MB 7.0 MB/s eta 0:00:02
#    ------- -------------------------------- 1.5/8.3 MB 7.4 MB/s eta 0:00:01
#    ------- -------------------------------- 1.5/8.3 MB 7.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.4/8.3 MB 8.6 MB/s eta 0:00:01
#    ------------- -------------------------- 2.9/8.3 MB 8.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.3/8.3 MB 8.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.3/8.3 MB 8.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.5/8.3 MB 7.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.8/8.3 MB 9.5 MB/s eta 0:00:01
#    ------------------------ --------------- 5.2/8.3 MB 9.8 MB/s eta 0:00:01
#    --------------------------- ------------ 5.6/8.3 MB 10.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.1/8.3 MB 10.1 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.3 MB 10.3 MB/s eta 0:00:01
#    --------------------------------- ------ 7.1/8.3 MB 10.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.1/8.3 MB 10.2 MB/s eta 0:00:01
#    -------------------------------------- - 8.0/8.3 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  8.3/8.3 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 10.2 MB/s eta 0:00:00
# Downloading joblib-1.6.0-py3-none-any.whl (306 kB)
#    ---------------------------------------- 0.0/306.1 kB ? eta -:--:--
#    ------------------------------------- - 297.0/306.1 kB 17.9 MB/s eta 0:00:01
#    ---------------------------------------- 306.1/306.1 kB 6.3 MB/s eta 0:00:00
# Downloading narwhals-2.26.0-py3-none-any.whl (474 kB)
#    ---------------------------------------- 0.0/474.0 kB ? eta -:--:--
#    ------------------------------------ -- 440.3/474.0 kB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 474.0/474.0 kB 9.9 MB/s eta 0:00:00
# Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#     --------------------------------------- 0.6/36.6 MB 11.5 MB/s eta 0:00:04
#    - -------------------------------------- 1.0/36.6 MB 10.8 MB/s eta 0:00:04
#    - -------------------------------------- 1.5/36.6 MB 12.2 MB/s eta 0:00:03
#    -- ------------------------------------- 2.1/36.6 MB 11.9 MB/s eta 0:00:03
#    -- ------------------------------------- 2.5/36.6 MB 12.4 MB/s eta 0:00:03
#    --- ------------------------------------ 3.0/36.6 MB 12.0 MB/s eta 0:00:03
#    --- ------------------------------------ 3.5/36.6 MB 11.8 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.0/36.6 MB 11.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.5/36.6 MB 12.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.0/36.6 MB 11.9 MB/s eta 0:00:03
#    ------ --------------------------------- 5.5/36.6 MB 12.1 MB/s eta 0:00:03
#    ------ --------------------------------- 5.9/36.6 MB 11.9 MB/s eta 0:00:03
#    ------- -------------------------------- 6.5/36.6 MB 11.8 MB/s eta 0:00:03
#    ------- -------------------------------- 7.0/36.6 MB 11.8 MB/s eta 0:00:03
#    -------- ------------------------------- 7.6/36.6 MB 11.8 MB/s eta 0:00:03
#    -------- ------------------------------- 8.0/36.6 MB 12.0 MB/s eta 0:00:03
#    --------- ------------------------------ 8.5/36.6 MB 11.8 MB/s eta 0:00:03
#    --------- ------------------------------ 9.0/36.6 MB 11.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 9.5/36.6 MB 11.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.0/36.6 MB 11.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 10.5/36.6 MB 11.9 MB/s eta 0:00:03
#    ------------ --------------------------- 11.0/36.6 MB 11.9 MB/s eta 0:00:03
#    ------------ --------------------------- 11.5/36.6 MB 11.9 MB/s eta 0:00:03
#    ------------- -------------------------- 12.0/36.6 MB 11.9 MB/s eta 0:00:03
#    ------------- -------------------------- 12.4/36.6 MB 11.9 MB/s eta 0:00:03
#    -------------- ------------------------- 13.0/36.6 MB 11.9 MB/s eta 0:00:02
#    -------------- ------------------------- 13.5/36.6 MB 11.9 MB/s eta 0:00:02
#    --------------- ------------------------ 14.0/36.6 MB 11.7 MB/s eta 0:00:02
#    --------------- ------------------------ 14.4/36.6 MB 11.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.0/36.6 MB 11.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.4/36.6 MB 11.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 15.9/36.6 MB 11.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.4/36.6 MB 11.7 MB/s eta 0:00:02
#    ------------------ --------------------- 16.8/36.6 MB 11.9 MB/s eta 0:00:02
#    ------------------ --------------------- 17.3/36.6 MB 11.9 MB/s eta 0:00:02
#    ------------------- -------------------- 17.8/36.6 MB 11.9 MB/s eta 0:00:02
#    ------------------- -------------------- 18.2/36.6 MB 11.7 MB/s eta 0:00:02
#    -------------------- ------------------- 18.7/36.6 MB 11.9 MB/s eta 0:00:02
#    -------------------- ------------------- 19.2/36.6 MB 11.7 MB/s eta 0:00:02
#    --------------------- ------------------ 19.7/36.6 MB 11.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 20.2/36.6 MB 11.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 20.6/36.6 MB 11.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 21.1/36.6 MB 11.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 21.6/36.6 MB 11.7 MB/s eta 0:00:02
#    ------------------------ --------------- 22.0/36.6 MB 11.9 MB/s eta 0:00:02
#    ------------------------ --------------- 22.6/36.6 MB 11.9 MB/s eta 0:00:02
#    ------------------------- -------------- 23.1/36.6 MB 11.9 MB/s eta 0:00:02
#    ------------------------- -------------- 23.6/36.6 MB 11.9 MB/s eta 0:00:02
#    -------------------------- ------------- 24.1/36.6 MB 11.9 MB/s eta 0:00:02
#    -------------------------- ------------- 24.5/36.6 MB 11.7 MB/s eta 0:00:02
#    --------------------------- ------------ 25.0/36.6 MB 11.9 MB/s eta 0:00:01
#    --------------------------- ------------ 25.5/36.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 25.9/36.6 MB 11.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 26.4/36.6 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 26.9/36.6 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 27.3/36.6 MB 11.7 MB/s eta 0:00:01
#    ------------------------------ --------- 27.8/36.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 28.4/36.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------- -------- 28.8/36.6 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 29.3/36.6 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 29.8/36.6 MB 11.7 MB/s eta 0:00:01
#    --------------------------------- ------ 30.3/36.6 MB 11.7 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 31.3/36.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 31.8/36.6 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 32.3/36.6 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 32.7/36.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 33.2/36.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 33.7/36.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 34.2/36.6 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 34.7/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------------------- - 35.2/36.6 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 35.7/36.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  36.1/36.6 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  36.6/36.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  36.6/36.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  36.6/36.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 10.6 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Installing collected packages: threadpoolctl, scipy, narwhals, cloudpickle, joblib, scikit-learn
# Successfully installed cloudpickle-3.1.2 joblib-1.6.0 narwhals-2.26.0 scikit-learn-1.9.1 scipy-1.17.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import MinMaxScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 from sklearn.preprocessing import MinMaxScaler
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
cols_to_scale = ['price', 'sqft_living', 'sqft_lot', 'price_per_sqft']

scaler = MinMaxScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 cols_to_scale = ['price', 'sqft_living', 'sqft_lot', 'price_per_sqft']
# ----> 3 scaler = MinMaxScaler()
#       4 df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])
#
# NameError: name 'MinMaxScaler' is not defined
