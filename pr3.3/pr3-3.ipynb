# %% [markdown]
# Звіт за результатами вивчення теми 3 слухача групи 5202 підполковника Жвавого Ігоря

# %%
import pandas as pd

   # Завантаження даних
df = pd.read_csv('war_history_economics_1948_2026.csv')

   # Перегляд перших рядків
print(df.head())
   
   # Огляд інформації про набір даних
print(df.info())
# Out:
#    Year Country  Military_Expenditure_Billion_USD  Active_Personnel  \
# 0  1948     USA                             50.97           1421958
# 1  1949     USA                             47.01           1437337
# 2  1950     USA                             75.96           2800000
# 3  1951     USA                             78.28           2800000
# 4  1952     USA                             96.22           2800000
#
#    GDP_Growth_Percent  Inflation_Rate_Percent  Conflict_Severity_Index  \
# 0                1.40                    4.55                        0
# 1                3.06                    6.03                        2
# 2                2.97                    3.35                        7
# 3                2.54                    1.72                        7
# 4                2.94                    0.70                        7
#
#   Significant_Event
# 0               NaN
# 1               NaN
# 2        Korean War
# 3        Korean War
# 4        Korean War
# ...

# %%
 # Перевірка на пропущені значення
print(df.isnull().sum())
# Out:
# Year                                  0
# Country                               0
# Military_Expenditure_Billion_USD      0
# Active_Personnel                      0
# GDP_Growth_Percent                    0
# Inflation_Rate_Percent                0
# Conflict_Severity_Index               0
# Significant_Event                   175
# dtype: int64

# %%
 # Заповнення пропущених значень середнім для числових стовпців
df.fillna(df.mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1  # Заповнення пропущених значень середнім для числових стовпців
# ----> 2 df.fillna(df.mean(), inplace=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:14475, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   14394 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
# ...

# %%
import pandas as pd

# Завантаження даних
df = pd.read_csv(
    r'C:\Users\day2026\Documents\Miaz 2026 practice works\pr3.3\war_history_economics_1948_2026.csv'
)

print("Дані успішно завантажено!")
# Out:
# Дані успішно завантажено!

# %%
print("\nПерші 5 рядків:")
print(df.head())
# Out:
# Перші 5 рядків:
#    Year Country  Military_Expenditure_Billion_USD  Active_Personnel  \
# 0  1948     USA                             50.97           1421958
# 1  1949     USA                             47.01           1437337
# 2  1950     USA                             75.96           2800000
# 3  1951     USA                             78.28           2800000
# 4  1952     USA                             96.22           2800000
#
#    GDP_Growth_Percent  Inflation_Rate_Percent  Conflict_Severity_Index  \
# 0                1.40                    4.55                        0
# 1                3.06                    6.03                        2
# 2                2.97                    3.35                        7
# 3                2.54                    1.72                        7
# 4                2.94                    0.70                        7
#
#   Significant_Event
# 0               NaN
# 1               NaN
# 2        Korean War
# 3        Korean War
# ...

# %%
print("\nІнформація про набір даних:")
print(df.info())
# Out:
# Інформація про набір даних:
# <class 'pandas.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Year                              237 non-null    int64
#  1   Country                           237 non-null    str
#  2   Military_Expenditure_Billion_USD  237 non-null    float64
#  3   Active_Personnel                  237 non-null    int64
#  4   GDP_Growth_Percent                237 non-null    float64
#  5   Inflation_Rate_Percent            237 non-null    float64
#  6   Conflict_Severity_Index           237 non-null    int64
#  7   Significant_Event                 62 non-null     str
# dtypes: float64(3), int64(3), str(2)
# memory usage: 14.9 KB
# None

# %%
print("\nРозмір таблиці:")
print(df.shape)
# Out:
# Розмір таблиці:
# (237, 8)

# %%
print("\nПропущені значення до обробки:")
print(df.isnull().sum())
# Out:
# Пропущені значення до обробки:
# Year                                  0
# Country                               0
# Military_Expenditure_Billion_USD      0
# Active_Personnel                      0
# GDP_Growth_Percent                    0
# Inflation_Rate_Percent                0
# Conflict_Severity_Index               0
# Significant_Event                   175
# dtype: int64

# %%
print("\nСтатистична інформація:")
print(df.describe())
# Out:
# Статистична інформація:
#              Year  Military_Expenditure_Billion_USD  Active_Personnel  \
# count   237.00000                        237.000000      2.370000e+02
# mean   1987.00000                        128.744895      7.841433e+05
# std      22.85177                        252.881599      6.956255e+05
# min    1948.00000                          0.500000      1.406980e+05
# 25%    1967.00000                          2.310000      1.867320e+05
# 50%    1987.00000                          6.130000      4.531770e+05
# 75%    2007.00000                        132.150000      1.396601e+06
# max    2026.00000                       1171.360000      3.000000e+06
#
#        GDP_Growth_Percent  Inflation_Rate_Percent  Conflict_Severity_Index
# count          237.000000              237.000000               237.000000
# mean             2.377215               12.583122                 2.713080
# std              2.822955               27.824136                 3.147833
# ...

# %%
print("\nКількість унікальних значень:")
print(df.nunique())
# Out:
# Кількість унікальних значень:
# Year                                 79
# Country                               3
# Military_Expenditure_Billion_USD    225
# Active_Personnel                    221
# GDP_Growth_Percent                  181
# Inflation_Rate_Percent              211
# Conflict_Severity_Index               9
# Significant_Event                    16
# dtype: int64

# %%
print("\nГотово! Очищений файл збережено.")
# Out:
# Готово! Очищений файл збережено.
